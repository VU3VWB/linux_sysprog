# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.fromfile("spidata.bin", dtype=np.uint16)
print (len(data))

plt.figure(figsize=(16,9))
plt.plot(data[0:1024])
# Out:
# 65536

# %%
plt.figure(figsize=(16,9))
plt.psd(data, Fs=2e3, NFFT=8192)
# Out:
# (array([3.54957300e+09, 1.77516687e+09, 1.16739852e+05, ...,
#         6.03926014e+05, 4.78318064e+05, 2.79999974e+05]),
#  array([0.00000000e+00, 2.44140625e-01, 4.88281250e-01, ...,
#         9.99511719e+02, 9.99755859e+02, 1.00000000e+03]))
