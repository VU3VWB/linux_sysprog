# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.fromfile("spidata.bin", dtype=np.uint16)
print (data)
# Out:
# [ 0  0  0 ... 64  0  0]

# %%
plt.figure(figsize=(16,9))
plt.plot(data)
